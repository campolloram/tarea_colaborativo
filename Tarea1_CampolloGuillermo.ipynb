# %% [markdown]
# # **Tarea 1 Portafolios de inversion**
#
# **Mis hobbies son:**
# - Deportes
#     * Futbol ![futbol.jpg](attachment:futbol.jpg)
#     * Basketbol ![basket.jpg](attachment:basket.jpg)
#     * Billar ![billar.jpg](attachment:billar.jpg)
# - Escolares
#     * Programar
#     * Finanzas
#     * Bolsa de valores
# - Extras
#     * Filosofia
#     * Ciencia
#     * Anatomia
# <br> <br> Me considero alguien activo, amable, dormilon, abierto a opiniones y muy inquieto. Cuando algo me llama la atencion puedo durar horas haciendolo pero si no me llama la atencion me cuesta trabajo dedicarle tiempo. <br><br><br><br><br>
#
# ## **Resumen de lectura numero1**
#
# la lecutra habla sobre como Python ha ganado muchos usuarios y ha derrocado a <br> otros lenguajes funcionales que estaban por arriba de el, pero a su vez habla sobre como <br> no podra derrocar a lenguajes de bajo nivel como C y C++ ya que estos se usan <br> para otros tipos de tareas.
